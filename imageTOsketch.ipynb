# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
import matplotlib.pyplot as plt

# %%
#read photo
img=cv2.imread('/content/drive/MyDrive/Colab Notebooks/photo.jpg')

# %%
#show image
cv2_imshow(img)
cv2.waitKey(0) 
cv2.destroyAllWindows()
#openCv uses BGR
#matplotlib uses RGB
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1500 at 0x7F4249496F70>

# %%
plt.imshow(img[:,:,::-1]) 
plt.axis(False) 
plt.show()

# %%
#1: Convert to Grey Image
grey_img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
grey_img_rgb=cv2.cvtColor(grey_img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(grey_img_rgb)
plt.axis(False) 
plt.show()

# %%
#2: Invert Image
invert_img=cv2.bitwise_not(grey_img)
invert_img_rgb=cv2.cvtColor(invert_img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(invert_img_rgb)
plt.axis(False) 
plt.show()

# %%
#3: Apply Gaussian Blur
blur_img_rgb=cv2.GaussianBlur(invert_img_rgb, (111,111),0)
blur_img=cv2.GaussianBlur(invert_img, (111,111),0)

# %%
plt.imshow(blur_img_rgb)
plt.axis(False) 
plt.show()

# %%
#4: Invert Blurred Image
invblur_img=cv2.bitwise_not(blur_img)
invblur_img_rgb=cv2.cvtColor(invblur_img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(invblur_img_rgb)
plt.axis(False) 
plt.show()

# %%
#5: Sketch
sketch_img=cv2.divide(grey_img,invblur_img, scale=256.0)
sketch_img_rgb=cv2.cvtColor(sketch_img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(sketch_img_rgb)
plt.axis(False) 
plt.show()

# %%
#6: Save Sketch
cv2.imwrite('sketch.png', sketch_img)
# Out:
# True

# %%
#7: Display sketch
cv2_imshow(sketch_img)
# Out:
# <PIL.Image.Image image mode=L size=1000x1500 at 0x7F42495F5C10>

# %%
plt.figure(figsize=(14,8))
plt.subplot(1,2,1) 
plt.title('Original image', size=18) 
img_og=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_og)
plt.axis('off')

plt.subplot(1,2,2)
plt.title('Sketch', size=18) 
rgb_sketch=cv2.cvtColor(sketch_img, cv2.COLOR_BGR2RGB) 
plt.imshow(rgb_sketch)
plt.axis('off')
plt.show()
